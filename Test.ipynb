# %% [markdown]
# # Sample Data Analysis Report
#
# This notebook demonstrates a simple data analysis workflow.

# %%
import pandas as pd
import numpy as np

# Sample data
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Score': [85, 92, 78]}
df = pd.DataFrame(data)
print(df)
# Out:
# Data Analysis Complete!

# %% [markdown]
# ## Summary Statistics

# %%
print(f"Mean Score: {df['Score'].mean()}")
print(f"Max Score: {df['Score'].max()}")
print(f"Min Score: {df['Score'].min()}")
# Out:
# Mean Score: 85.0
# Max Score: 92
# Min Score: 78

# %% [markdown]
# ---
#
# **Conclusion:** All students passed the assessment.
